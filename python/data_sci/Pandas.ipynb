# %%
import pandas as pd
import matplotlib 
pd.__version__
# Out:
# '0.23.0'

# %%
pd.Series(['San Frans','San Jose','Sacramento'])
# Out:
# 0     San Frans
# 1      San Jose
# 2    Sacramento
# dtype: object

# %%
city_names = pd.Series(['San Frans','San Jose','Sacramento'])
population = pd.Series([31434,981389,4453])
cities = pd.DataFrame({'City name':city_names,'Population':population})

# %%
california_housing_dataframe = pd.read_csv("https://storage.googleapis.com/mledu-datasets/california_housing_train.csv", sep=",")

# %%
california_housing_dataframe.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
california_housing_dataframe.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
california_housing_dataframe.hist('housing_median_age')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f03b116a9b0>]],
#       dtype=object)

# %%
population/1000
# Out:
# 0     31.434
# 1    981.389
# 2      4.453
# dtype: float64

# %%
import numpy as np

# %%
np.log(population)
# Out:
# 0    10.355645
# 1    13.796724
# 2     8.401333
# dtype: float64

# %%
cities
# Out:
#     City name  Population
# 0   San Frans       31434
# 1    San Jose      981389
# 2  Sacramento        4453

# %%
cities['Area square miles'] = pd.Series([46.87,99,38.0])

# %%
cities
# Out:
#     City name  Population  Area square miles
# 0   San Frans       31434              46.87
# 1    San Jose      981389              99.00
# 2  Sacramento        4453              38.00

# %%
cities['Population density'] = cities['Population'] / cities['Area square miles']
cities
# Out:
#     City name  Population  Area square miles  Population density
# 0   San Frans       31434              46.87          670.663537
# 1    San Jose      981389              99.00         9913.020202
# 2  Sacramento        4453              38.00          117.184211

# %%
population
# Out:
# 0     31434
# 1    981389
# 2      4453
# dtype: int64

# %%
population.apply(lambda val: val > 40000)
# Out:
# 0    False
# 1     True
# 2    False
# dtype: bool

# %%
cities['boolean'] = cities['Area square miles']>50

# %%
cities
# Out:
#    City name   Population  Area square miles  Population density  boolean
# 0   San Frans       31434              46.87          670.663537    False
# 1    San Jose      981389              99.00         9913.020202     True
# 2  Sacramento        4453              38.00          117.184211    False

# %%
cities['name_bool']=cities['City name'].apply(lambda name: name.startswith('San'))
cities
# Out:
#     City name  Population  Area square miles  Population density  boolean  \
# 0   San Frans       31434              46.87          670.663537    False
# 1    San Jose      981389              99.00         9913.020202     True
# 2  Sacramento        4453              38.00          117.184211    False
#
#    name_bool
# 0       True
# 1       True
# 2      False

# %%
cities['bool_fin']=cities['boolean'] & cities['name_bool']

# %%
cities
# Out:
#     City name  Population  Area square miles  Population density  boolean  \
# 0   San Frans       31434              46.87          670.663537    False
# 1    San Jose      981389              99.00         9913.020202     True
# 2  Sacramento        4453              38.00          117.184211    False
#
#    name_bool  bool_fin
# 0       True     False
# 1       True      True
# 2      False     False

# %%
cities.reindex([2,0,1])
# Out:
#     City name  Population  Area square miles  Population density  boolean  \
# 2  Sacramento        4453              38.00          117.184211    False
# 0   San Frans       31434              46.87          670.663537    False
# 1    San Jose      981389              99.00         9913.020202     True
#
#    name_bool  bool_fin
# 2      False     False
# 0       True     False
# 1       True      True
