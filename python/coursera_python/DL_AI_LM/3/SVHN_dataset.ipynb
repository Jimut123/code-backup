# %%
# !wget "ufldl.stanford.edu/housenumbers/train.tar.gz"
# Out:
# --2019-12-27 20:20:46--  http://ufldl.stanford.edu/housenumbers/train.tar.gz
# Resolving ufldl.stanford.edu (ufldl.stanford.edu)... 171.64.68.10
# Connecting to ufldl.stanford.edu (ufldl.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 404141560 (385M) [application/x-gzip]
# Saving to: ‘train.tar.gz’
#
# train.tar.gz        100%[===================>] 385.42M  20.3MB/s    in 25s
#
# 2019-12-27 20:21:11 (15.3 MB/s) - ‘train.tar.gz’ saved [404141560/404141560]

# %% [markdown]
# This dataset is got from here: http://ufldl.stanford.edu/housenumbers/

# %%
# !wget "ufldl.stanford.edu/housenumbers/test.tar.gz"
# Out:
# --2019-12-27 20:21:17--  http://ufldl.stanford.edu/housenumbers/test.tar.gz
# Resolving ufldl.stanford.edu (ufldl.stanford.edu)... 171.64.68.10
# Connecting to ufldl.stanford.edu (ufldl.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 276555967 (264M) [application/x-gzip]
# Saving to: ‘test.tar.gz’
#
# test.tar.gz         100%[===================>] 263.74M  20.0MB/s    in 19s
#
# 2019-12-27 20:21:36 (14.0 MB/s) - ‘test.tar.gz’ saved [276555967/276555967]

# %%
ls
# Out:
# sample_data/  test.tar.gz  train.tar.gz

# %%
# !tar -xvzf test.tar.gz
# Out:
# test/
# test/1809.png
# test/1757.png
# test/1749.png
# test/1746.png
# test/1731.png
# test/1723.png
# test/1715.png
# test/1707.png
# test/1701.png
# test/1681.png
# test/1671.png
# test/1653.png
# test/1645.png
# test/1627.png
# test/1626.png
# test/1599.png
# test/1564.png
# test/1537.png
# test/1529.png
# test/1499.png
# test/1487.png
# test/1484.png
# test/1466.png
# test/1394.png
# test/1389.png
# test/1381.png
# test/1356.png
# test/1342.png
# test/1333.png
# test/1277.png
# test/1262.png
# test/1257.png
# test/1253.png
# test/1246.png
# test/1229.png
# test/1215.png
# test/1208.png
# test/1201.png
# test/1171.png
# test/1166.png
# test/1158.png
# test/1143.png
# test/1140.png
# test/1134.png
# test/1126.png
# test/1106.png
# test/1104.png
# test/1075.png
# test/1038.png
# test/1025.png
# test/981.png
# test/978.png
# test/950.png
# test/949.png
# test/946.png
# test/939.png
# test/937.png
# test/934.png
# test/929.png
# test/912.png
# test/903.png
# test/898.png
# ...

# %%
pwd test/3101.png
# Out:
# '/content'

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
% matplotlib inline

# %%
"test/3731.png"

directory=os.listdir('test/')
#for each in directory:
plt.figure()
currentFolder = 'test/'
for i, file in enumerate(os.listdir(currentFolder)[0:5]):
    fullpath = 'test'+ "/" + file
    print(fullpath)
    img=mpimg.imread(fullpath)
    plt.subplot(2, 3, i+1)
    plt.imshow(img)
# Out:
# test/6800.png
# test/9462.png
# test/2408.png
# test/10727.png
# test/2120.png

# %%
# ls /content/test/6800.png

# %%
# directory=os.listdir('test/')
# directory

# !wget "ufldl.stanford.edu/housenumbers/train_32x32.mat"
# !wget "ufldl.stanford.edu/housenumbers/test_32x32.mat"
# Out:
# --2019-12-27 20:43:37--  http://ufldl.stanford.edu/housenumbers/train_32x32.mat
# Resolving ufldl.stanford.edu (ufldl.stanford.edu)... 171.64.68.10
# Connecting to ufldl.stanford.edu (ufldl.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 182040794 (174M) [text/plain]
# Saving to: ‘train_32x32.mat’
#
# train_32x32.mat     100%[===================>] 173.61M  20.2MB/s    in 14s
#
# 2019-12-27 20:43:51 (12.1 MB/s) - ‘train_32x32.mat’ saved [182040794/182040794]
#
# --2019-12-27 20:43:54--  http://ufldl.stanford.edu/housenumbers/test_32x32.mat
# Resolving ufldl.stanford.edu (ufldl.stanford.edu)... 171.64.68.10
# Connecting to ufldl.stanford.edu (ufldl.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 64275384 (61M) [text/plain]
# Saving to: ‘test_32x32.mat’
#
# test_32x32.mat      100%[===================>]  61.30M  13.8MB/s    in 9.3s
#
# ...

# %%
# !ls
# Out:
# sample_data  test  test_32x32.mat  test.tar.gz	train_32x32.mat  train.tar.gz

# %%
from scipy.io import loadmat
train_data = loadmat('train_32x32.mat')
test_data = loadmat('test_32x32.mat')
#f = h5py.File('train_32x32.mat','r')

# %%
print(train_data)
print(test_data)
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: GLNXA64, Created on: Mon Dec  5 21:09:26 2011', '__version__': '1.0', '__globals__': [], 'X': array([[[[ 33,  84,  19, ...,  92, 190, 216],
#          [ 30,  76,  54, ...,  78, 188, 217],
#          [ 38,  59, 110, ..., 101, 191, 212]],
#
#         [[ 15,  86,  20, ...,  94, 205, 221],
#          [ 23,  73,  52, ...,  82, 203, 222],
#          [ 19,  66, 111, ..., 105, 206, 217]],
#
#         [[ 15,  77,  25, ..., 114, 220, 226],
#          [ 17,  78,  57, ..., 101, 218, 227],
#          [ 19,  56, 116, ..., 125, 220, 221]],
#
#         ...,
#
#         [[ 72,  90,  65, ..., 200, 229, 200],
#          [ 65,  78, 144, ..., 201, 231, 199],
#          [ 56,  69, 223, ..., 203, 224, 191]],
#
#         [[ 82,  88,  78, ..., 192, 229, 193],
#          [ 77,  77, 148, ..., 193, 229, 188],
#          [ 57,  67, 218, ..., 195, 224, 182]],
#
#         [[ 89,  88,  98, ..., 190, 229, 197],
#          [ 79,  78, 158, ..., 191, 228, 189],
# ...
